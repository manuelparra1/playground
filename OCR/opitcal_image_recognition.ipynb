# %%
import pytesseract
from PIL import Image
import cv2

# %%
pytesseract.pytesseract.tesseract_cmd = r'/opt/homebrew/Cellar/tesseract/5.3.0_1/bin/tesseract'
config = ('-l eng --oem 1 --psm 3')

# %%
screenshot = Image.open('screenshot.png')

# %%
text = pytesseract.image_to_string(screenshot,lang=None)

# %%
screenshot
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1350x816>

# %%
print(text)
# Out:
# Continuous with Continuous
#
# e Seaborn pairplot to create a scatter matrix visualizing all continous variable
# relationships along with individiual distributions.
#
# | sns.pairplot (data)
#
# e Seaborn relplot for a simple scatter plot of two continuous variables.
# | sns.relplot(x, y, data, kind=scatter)
#
# e Seaborn 1mplot for a simple scatter plot of two continous variables with a
# regression line. | can pass a discrete variable to col or hue to bring in another
#
# dimension, too.
#
# | sns.lmplot(x, y, data, scatter=True, hue=None, col=None)
